# %%
# https://data.cityofchicago.org/Transportation/Taxi-Trips-2013-2023-/wrvz-psew/about_data

import requests
import pandas as pd
import json
import time
import os
from datetime import datetime, timedelta

SAVE_DIR = "../../data/raw data"
SUB_FOLDER = "2019"
os.makedirs(SAVE_DIR, exist_ok=True)

# Socrata API endpoint
BASE_URL = "https://data.cityofchicago.org/resource/wrvz-psew.json"

# SODA 2.1 API Parameters (Using SQL-like query)
LIMIT = 100000  # Maximum records per request
WINDOW_SIZE = 1
DATA = []

def fetch_data(start_date, end_date):
    OFFSET = 0
    temp_data = []

    start_time = f"{start_date}T00:00:00"
    end_time = f"{end_date}T23:59:59"

    while True:
        query = f"""
            SELECT * 
            WHERE trip_start_timestamp BETWEEN '{start_time}' AND '{end_time}'
            ORDER BY trip_start_timestamp ASC
            LIMIT {LIMIT} OFFSET {OFFSET}
        """

        params = {"$query": query}  # Using SODA 2.1 SQL query
        response = requests.get(BASE_URL, params=params)

        if response.status_code != 200:
            print(f"❌ Error: {response.status_code} - {response.text}")
            break

        records = response.json()

        if not records:
            print("✅ No more data available. Fetching completed.")
            break

        temp_data.extend(records)
        print(f"✅ Fetched {len(records)} records, total: {len(temp_data)} records.")

        OFFSET += LIMIT  # Increase offset for pagination
        time.sleep(1)  # Prevent rate limiting

    return temp_data

start_date = datetime(2018, 11, 1)
final_date = datetime(2019, 2, 21)

# Fetch data
while start_date <= final_date:
    target_date = start_date.strftime('%Y-%m-%d')
    print(f"\n🔄 Fetching data for {target_date}...")

    daily_data = fetch_data(target_date, target_date)

    if daily_data:
        DATA.extend(daily_data)

    start_date += timedelta(days=WINDOW_SIZE)

# **Convert and save as CSV**
df = pd.DataFrame(DATA)
csv_file = os.path.join(SAVE_DIR, SUB_FOLDER, "chicago_taxi_trips.csv")
df.to_csv(csv_file, index=False)
print(f"📁 Data saved to {csv_file}")
# Out:
# 🔄 Fetching data for 2018-11-01...
# ✅ Fetched 62836 records, total: 62836 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-11-02...
# ✅ Fetched 62349 records, total: 62349 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-11-03...
# ✅ Fetched 45540 records, total: 45540 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-11-04...
# ✅ Fetched 40978 records, total: 40978 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-11-05...
# ✅ Fetched 53156 records, total: 53156 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-11-06...
# ✅ Fetched 58419 records, total: 58419 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-11-07...
# ✅ Fetched 63993 records, total: 63993 records.
# ❌ Error: 500 - {"message":"Internal error: please include code 3a7c776e-e68f-418a-b11f-3f58020e6884 if you report the error","errorCode":"internal-error","data":{"tag":"3a7c776e-e68f-418a-b11f-3f58020e6884"}}
#
# 🔄 Fetching data for 2018-11-08...
# ❌ Error: 500 - {"message":"Internal error: please include code 446ed883-6739-4e7d-aebc-2e6d7fb94d24 if you report the error","errorCode":"internal-error","data":{"tag":"446ed883-6739-4e7d-aebc-2e6d7fb94d24"}}
#
# 🔄 Fetching data for 2018-11-09...
# ✅ Fetched 69255 records, total: 69255 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-11-10...
# ✅ Fetched 46664 records, total: 46664 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-11-11...
# ✅ Fetched 41242 records, total: 41242 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-11-12...
# ✅ Fetched 50506 records, total: 50506 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-11-13...
# ✅ Fetched 58212 records, total: 58212 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-11-14...
# ✅ Fetched 63388 records, total: 63388 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-11-15...
# ✅ Fetched 68634 records, total: 68634 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-11-16...
# ✅ Fetched 67183 records, total: 67183 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-11-17...
# ✅ Fetched 42115 records, total: 42115 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-11-18...
# ✅ Fetched 35645 records, total: 35645 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-11-19...
# ✅ Fetched 47274 records, total: 47274 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-11-20...
# ✅ Fetched 49674 records, total: 49674 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-11-21...
# ✅ Fetched 40428 records, total: 40428 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-11-22...
# ✅ Fetched 20192 records, total: 20192 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-11-23...
# ✅ Fetched 30217 records, total: 30217 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-11-24...
# ✅ Fetched 39253 records, total: 39253 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-11-25...
# ✅ Fetched 38849 records, total: 38849 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-11-26...
# ✅ Fetched 52913 records, total: 52913 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-11-27...
# ✅ Fetched 68636 records, total: 68636 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-11-28...
# ✅ Fetched 66769 records, total: 66769 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-11-29...
# ✅ Fetched 65083 records, total: 65083 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-11-30...
# ✅ Fetched 62897 records, total: 62897 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-01...
# ✅ Fetched 45612 records, total: 45612 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-02...
# ✅ Fetched 34165 records, total: 34165 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-03...
# ✅ Fetched 52613 records, total: 52613 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-04...
# ✅ Fetched 57647 records, total: 57647 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-05...
# ✅ Fetched 60205 records, total: 60205 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-06...
# ✅ Fetched 69493 records, total: 69493 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-07...
# ✅ Fetched 71871 records, total: 71871 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-08...
# ✅ Fetched 48673 records, total: 48673 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-09...
# ✅ Fetched 37110 records, total: 37110 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-10...
# ✅ Fetched 52648 records, total: 52648 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-11...
# ✅ Fetched 55759 records, total: 55759 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-12...
# ✅ Fetched 60919 records, total: 60919 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-13...
# ✅ Fetched 68139 records, total: 68139 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-14...
# ✅ Fetched 67864 records, total: 67864 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-15...
# ✅ Fetched 47183 records, total: 47183 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-16...
# ✅ Fetched 36479 records, total: 36479 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-17...
# ✅ Fetched 50054 records, total: 50054 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-18...
# ✅ Fetched 55866 records, total: 55866 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-19...
# ✅ Fetched 57863 records, total: 57863 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-20...
# ✅ Fetched 60306 records, total: 60306 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-21...
# ✅ Fetched 57645 records, total: 57645 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-22...
# ✅ Fetched 37061 records, total: 37061 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-23...
# ✅ Fetched 27332 records, total: 27332 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-24...
# ✅ Fetched 20820 records, total: 20820 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-25...
# ✅ Fetched 9843 records, total: 9843 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-26...
# ✅ Fetched 26471 records, total: 26471 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-27...
# ✅ Fetched 36616 records, total: 36616 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-28...
# ✅ Fetched 39496 records, total: 39496 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-29...
# ✅ Fetched 32113 records, total: 32113 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-30...
# ✅ Fetched 28826 records, total: 28826 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2018-12-31...
# ✅ Fetched 36154 records, total: 36154 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-01...
# ✅ Fetched 28100 records, total: 28100 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-02...
# ✅ Fetched 33695 records, total: 33695 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-03...
# ✅ Fetched 39012 records, total: 39012 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-04...
# ✅ Fetched 40885 records, total: 40885 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-05...
# ✅ Fetched 27657 records, total: 27657 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-06...
# ✅ Fetched 26826 records, total: 26826 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-07...
# ✅ Fetched 40534 records, total: 40534 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-08...
# ✅ Fetched 42990 records, total: 42990 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-09...
# ✅ Fetched 49408 records, total: 49408 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-10...
# ✅ Fetched 52901 records, total: 52901 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-11...
# ✅ Fetched 51957 records, total: 51957 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-12...
# ✅ Fetched 31332 records, total: 31332 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-13...
# ✅ Fetched 24230 records, total: 24230 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-14...
# ✅ Fetched 41861 records, total: 41861 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-15...
# ✅ Fetched 47817 records, total: 47817 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-16...
# ✅ Fetched 50291 records, total: 50291 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-17...
# ✅ Fetched 52676 records, total: 52676 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-18...
# ✅ Fetched 50871 records, total: 50871 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-19...
# ✅ Fetched 28521 records, total: 28521 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-20...
# ✅ Fetched 26672 records, total: 26672 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-21...
# ✅ Fetched 31281 records, total: 31281 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-22...
# ✅ Fetched 49851 records, total: 49851 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-23...
# ✅ Fetched 53168 records, total: 53168 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-24...
# ✅ Fetched 56742 records, total: 56742 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-25...
# ✅ Fetched 52646 records, total: 52646 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-26...
# ✅ Fetched 29665 records, total: 29665 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-27...
# ✅ Fetched 25461 records, total: 25461 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-28...
# ✅ Fetched 39345 records, total: 39345 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-29...
# ✅ Fetched 44538 records, total: 44538 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-30...
# ✅ Fetched 14029 records, total: 14029 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-01-31...
# ✅ Fetched 28567 records, total: 28567 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-02-01...
# ✅ Fetched 51769 records, total: 51769 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-02-02...
# ✅ Fetched 28986 records, total: 28986 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-02-03...
# ✅ Fetched 24617 records, total: 24617 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-02-04...
# ✅ Fetched 45113 records, total: 45113 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-02-05...
# ✅ Fetched 48970 records, total: 48970 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-02-06...
# ✅ Fetched 50951 records, total: 50951 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-02-07...
# ✅ Fetched 58604 records, total: 58604 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-02-08...
# ✅ Fetched 58708 records, total: 58708 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-02-09...
# ✅ Fetched 32331 records, total: 32331 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-02-10...
# ✅ Fetched 26563 records, total: 26563 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-02-11...
# ✅ Fetched 47204 records, total: 47204 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-02-12...
# ✅ Fetched 51928 records, total: 51928 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-02-13...
# ✅ Fetched 55329 records, total: 55329 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-02-14...
# ✅ Fetched 52286 records, total: 52286 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-02-15...
# ✅ Fetched 56903 records, total: 56903 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-02-16...
# ✅ Fetched 36876 records, total: 36876 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-02-17...
# ✅ Fetched 30717 records, total: 30717 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-02-18...
# ✅ Fetched 37369 records, total: 37369 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-02-19...
# ✅ Fetched 50721 records, total: 50721 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-02-20...
# ✅ Fetched 56284 records, total: 56284 records.
# ✅ No more data available. Fetching completed.
#
# 🔄 Fetching data for 2019-02-21...
# ✅ Fetched 60955 records, total: 60955 records.
# ✅ No more data available. Fetching completed.
# 📁 Data saved to ../../data/raw data/2019/chicago_taxi_trips.csv
